# %% [markdown]
# # Python Notebook Exercise - Data Skills Week 4
# auth: Cristian Hernandez

# %%
import pandas as pd

# %%
morrowplots_df = pd.read_csv("../data/raw/morrowplots.csv")

# %%
morrowplots_df
# Out:
#       Unnamed: 0  phase  year plot  plot_num plot_dir  rotation  corn crop  \
# 0              1      1  1888  3NA         3       NW       1.0  True   CC
# 1              2      1  1888  3NB         3       NW       1.0  True   CC
# 2              3      1  1888  3NC         3       NE       1.0  True   CC
# 3              4      1  1888  3ND         3       NE       1.0  True   CC
# 4              5      1  1888  3SA         3       SW       1.0  True   CC
# ...          ...    ...   ...  ...       ...      ...       ...   ...  ...
# 3211        3212      5  2021  5ND         5       NE       3.0  True    C
# 3212        3213      5  2021  5SA         5       SW       3.0  True    C
# 3213        3214      5  2021  5SB         5       SW       3.0  True    C
# 3214        3215      5  2021  5SC         5       SE       3.0  True    C
# 3215        3216      5  2021  5SD         5       SE       3.0  True    C
#
# ...

# %%
mpcorn_df = morrowplots_df[morrowplots_df['corn']==True]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
# seaborn makes it easier to handle grouped aesthetics like color + linetype
sns.lineplot(
    data=mpcorn_df,
    x="year",
    y="yield_bush",
    hue="rotation",
    style="treated",
    lw=2
)
plt.title("Morrow Plots Corn Yield Trends in Bushels per Acre")
plt.xlabel("Year")
plt.ylabel("Yield (bushels per acre)")
plt.legend(title="Rotation / Treated", bbox_to_anchor=(1.05, 1), loc="upperleft")
plt.tight_layout()
plt.show()
# Out:
#   Cell In[18], line 2
#     import seaborn-base as sns
#                   ^
# SyntaxError: invalid syntax

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     /home/cgherz/conda
# dataskills-w1            /home/cgherz/conda/envs/dataskills-w1
# dataskills-w2            /home/cgherz/conda/envs/dataskills-w2
# dataskills-w4        *   /home/cgherz/conda/envs/dataskills-w4
# grampa-env               /home/cgherz/conda/envs/grampa-env
# phylo                    /home/cgherz/conda/envs/phylo

# %%
# !conda list
# Out:
# # packages in environment at /home/cgherz/conda/envs/dataskills-w4:
# #
# # Name                           Version          Build                 Channel
# _openmp_mutex                    4.5              20_gnu                conda-forge
# _python_abi3_support             1.0              hd8ed1ab_3            conda-forge
# alsa-lib                         1.2.16.1         h7cc23a3_1            conda-forge
# anyio                            4.15.1           pyh5ded981_1          conda-forge
# argon2-cffi                      25.1.0           pyhd8ed1ab_0          conda-forge
# argon2-cffi-bindings             26.1.0           py314h89acca1_1       conda-forge
# arrow                            1.4.0            pyhcf101f3_0          conda-forge
# asttokens                        3.0.2            pyhd8ed1ab_0          conda-forge
# async-lru                        2.3.0            pyhcf101f3_0          conda-forge
# ...
